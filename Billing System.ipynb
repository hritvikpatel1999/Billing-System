# %%
from tkinter import*
import math,random
from tkinter import messagebox
from tkinter import simpledialog
from tkinter.ttk import Notebook
import pandas as pd
import numpy as np
from datetime import date
import os

daily = pd.read_excel(r'C:\Users\hritv\bills\accounts.xlsx')


# price = {   "lakh":120,
#              "chandrush": 95,
#              "spirit": 80,
#              "white": 140,
#              "lakh_pwd": 1000,
#              "chandrush_pwd": 400,
#              "rajan": 400,
#              "thinner": 90,
#              "alo_80": 12,
#              "alo_120": 10,
#              "sandpaper": 4,
#              "rollpaper": 50,
#              "tukda": 10,
#              "amber": 10,
#              "kesari": 20,
#              "zinc": 60,
#              "dk": 140,
#              "woodmatte": 400,
#              "woodglossy": 350,
#              "sealer": 250,
#              "saree": 60,
#              "momplain": 400,
#              "mommatte": 600,
#              "brush": 15
#          }

# cost = { "lakh":91,
#              "chandrush": 71,
#              "spirit": 55,
#              "white": 0,
#              "lakh_pwd": 650,
#              "chandrush_pwd": 160,
#              "rajan": 150,
#              "thinner": 0,
#              "alo_80": 0,
#              "alo_120": 0,
#              "sandpaper": 0,
#              "rollpaper": 0,
#              "tukda": 0,
#              "amber": 0,
#              "kesari": 0,
#              "zinc": 0,
#              "dk": 0,
#              "woodmatte": 0,
#              "woodglossy": 0,
#              "sealer": 0,
#              "saree": 0,
#              "momplain": 0,
#              "mommatte": 0,
#              "brush": 0
#          }

# stock = { "lakh":0,
#              "chandrush": 0,
#              "spirit": 0,
#              "white": 0,
#              "lakh_pwd": 0,
#              "chandrush_pwd": 0,
#              "rajan": 0,
#              "thinner": 0,
#              "alo_80": 0,
#              "alo_120": 0,
#              "sandpaper": 0,
#              "rollpaper": 0,
#              "tukda": 0,
#              "amber": 0,
#              "kesari": 0,
#              "zinc": 0,
#              "dk": 0,
#              "woodmatte": 0,
#              "woodglossy": 0,
#              "sealer": 0,
#              "saree": 0,
#              "momplain": 0,
#              "mommatte": 0,
#              "brush": 0
#          }

# quantity = { "lakh":0,
#              "chandrush": 0,
#              "spirit": 0,
#              "white": 0,
#              "lakh_pwd": 0,
#              "chandrush_pwd": 0,
#              "rajan": 0,
#              "thinner": 0,
#              "alo_80": 0,
#              "alo_120": 0,
#              "sandpaper": 0,
#              "rollpaper": 0,
#              "tukda": 0,
#              "amber": 0,
#              "kesari": 0,
#              "zinc": 0,
#              "dk": 0,
#              "woodmatte": 0,
#              "woodglossy": 0,
#              "sealer": 0,
#              "saree": 0,
#              "momplain": 0,
#              "mommatte": 0,
#              "brush": 0
#          }

# quantity_day = { "lakh":0,
#              "chandrush": 0,
#              "spirit": 0,
#              "white": 0,
#              "lakh_pwd": 0,
#              "chandrush_pwd": 0,
#              "rajan": 0,
#              "thinner": 0,
#              "alo_80": 0,
#              "alo_120": 0,
#              "sandpaper": 0,
#              "rollpaper": 0,
#              "tukda": 0,
#              "amber": 0,
#              "kesari": 0,
#              "zinc": 0,
#              "dk": 0,
#              "woodmatte": 0,
#              "woodglossy": 0,
#              "sealer": 0,
#              "saree": 0,
#              "momplain": 0,
#              "mommatte": 0,
#              "brush": 0
#          }

# quantity_month = { "lakh":0,
#              "chandrush": 0,
#              "spirit": 0,
#              "white": 0,
#              "lakh_pwd": 0,
#              "chandrush_pwd": 0,
#              "rajan": 0,
#              "thinner": 0,
#              "alo_80": 0,
#              "alo_120": 0,
#              "sandpaper": 0,
#              "rollpaper": 0,
#              "tukda": 0,
#              "amber": 0,
#              "kesari": 0,
#              "zinc": 0,
#              "dk": 0,
#              "woodmatte": 0,
#              "woodglossy": 0,
#              "sealer": 0,
#              "saree": 0,
#              "momplain": 0,
#              "mommatte": 0,
#              "brush": 0
#          }

products = ["lakh","chandrush","spirit", "white","lakh_pwd","chandrush_pwd","rajan", "thinner", "alo_80", "alo_120","sandpaper","rollpaper",
           "tukda","amber","kesari","zinc","dk","woodmatte","woodglossy","sealer","saree","momplain","mommatte","brush"]

price = {}
count=0
with open("bills/price.txt") as fo:
    for rec in fo:
        price[products[count]] = float(rec.split(",")[0])
        count +=1
        
cost = {}
count=0
with open("bills/cost.txt") as fo:
    for rec in fo:
        cost[products[count]] = float(rec.split(",")[0])
        count +=1

quantity = {}        
quantity_day = {}
count=0
with open("bills/quantity_day.txt") as fo:
    for rec in fo:
        quantity_day[products[count]] = float(rec.split(",")[0])
        count +=1
        
quantity_month = {}
count=0
with open("bills/quantity_month.txt") as fo:
    for rec in fo:
        quantity_month[products[count]] = float(rec.split(",")[0])
        count +=1

stock = {}
total_stock = {}
count=0
with open("bills/stock_total.txt") as fo:
    for rec in fo:
        total_stock[products[count]] = float(rec.split(",")[0])
        count +=1

profit_curr = {}        
        
daily_profit = 0.0
total_profit = 0.0
monthly_profit = 0.0

# print(price)
# print(cost)

class Bill_App:
    def __init__(self,root):
        self.root = root
        self.root.geometry("1350x750+0+0")
        self.root.title("Billing Software")
        bg_color = "#074463"
        title = Label(self.root, text="SUPREME TRADERS", bd=12, relief=GROOVE, bg=bg_color, fg="white", font=("times new roman", 30,"bold"), pady=2).pack(fill=X)
        
        #==========VARIABLES==========#
        
        #CUSTOMER#
        self.cust_name = StringVar()
        self.phone = StringVar()
        self.billno = StringVar()
        x = random.randint(1000,9999)
        self.billno.set(str(x))
        self.search_bill = StringVar()
        
        #POLISH#
        self.lakh = DoubleVar()
        self.chandrush = DoubleVar()
        self.spirit = DoubleVar()
        self.white = DoubleVar()
        self.lakh_pwd = DoubleVar()
        self.chandrush_pwd = DoubleVar()
        self.rajan = DoubleVar()
        self.thinner = DoubleVar()
        
        #P&P#
        self.alo_80 = DoubleVar()
        self.alo_120 = DoubleVar()
        self.sandpaper = DoubleVar()
        self.rollpaper = DoubleVar()
        self.tukda = DoubleVar()
        self.amber = DoubleVar()
        self.kesari = DoubleVar()
        self.zinc = DoubleVar()
        
        #OTHERS#
        self.dk = DoubleVar()
        self.woodmatte = DoubleVar()
        self.woodglossy = DoubleVar()
        self.sealer = DoubleVar()
        self.saree = DoubleVar()
        self.momplain = DoubleVar()
        self.mommatte = DoubleVar()
        self.brush = IntVar()
        
        #TOTAL & TAX#
        self.tot_polish = DoubleVar()
        self.tot_pp = DoubleVar()
        self.tot_other = DoubleVar()
        self.tax_polish = DoubleVar()
        self.tax_pp = DoubleVar()
        self.tax_other = DoubleVar()
        self.total_bill = DoubleVar()
        
        #==========PASSWORD==========#
        self.password = StringVar()
        self.password.set("hitesh")
        
        #========CUSTOMER DETAILS GO IN HERE==========#
        F1=LabelFrame(self.root, bd=10, relief=GROOVE, text="Customer Details", font=("times new roman", 15, "bold"), fg="gold", bg=bg_color)
        F1.place(x=0, y=80, relwidth=1)
        
        cname_lbl=Label(F1, text="Customer Name", bg=bg_color, fg="white", font=("times new roman", 15, "bold")).grid(row=0, column=0, padx=20, pady=5)
        cname_txt=Entry(F1, width=18, textvariable=self.cust_name, font="arial 15", bd=7, relief=SUNKEN).grid(row=0, column=1, padx=10, pady=5)
        
        cphone_lbl=Label(F1, text="Phone Number", bg=bg_color, fg="white", font=("times new roman", 15, "bold")).grid(row=0, column=2, padx=20, pady=5)
        cphone_txt=Entry(F1, width=18, textvariable=self.phone, font="arial 15", bd=7, relief=SUNKEN).grid(row=0, column=3, padx=10, pady=5)
        
        cbill_lbl=Label(F1, text="Bill Number", bg=bg_color, fg="white", font=("times new roman", 15, "bold")).grid(row=0, column=4, padx=20, pady=5)
        cbill_txt=Entry(F1, width=18, textvariable=self.search_bill, font="arial 15", bd=7, relief=SUNKEN).grid(row=0, column=5, padx=10, pady=5)
        
        bill_btn=Button(F1, text="Search", width=10, bd=7, font="arial 12 bold").grid(row=0, column=6, pady=10, padx=10)
        
        
        #==========COSMETIC FRAME==========#
        F2=LabelFrame(self.root, bd=10, relief=GROOVE, text="Polish", font=("times new roman", 15, "bold"), fg="gold", bg=bg_color)
        F2.place(x=5, y=180, width=350, height=405)
        
        #bath_lbl = Label(F2, text="Chandrush", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=0, column=1, padx=10,pady=10)
        #bath_txt = Entry(F2, width=10, font("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=0,column=1,padx=10,pady=10)
        
        lakh_lbl = Label(F2, text="Lac Polish (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=0,column=0,padx=5,pady=5,sticky="w")
        lakh_txt = Entry(F2, width=8, textvariable=self.lakh, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=0,column=1,padx=5,pady=5)
        
        chandrush_lbl = Label(F2, text="Chandrush (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=1,column=0,padx=5,pady=5,sticky="w")
        chandrush_txt = Entry(F2, width=8,textvariable=self.chandrush, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=1,column=1,padx=5,pady=5)
        
        spirit_lbl = Label(F2, text="Spirit (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=2,column=0,padx=5,pady=5,sticky="w")
        spirit_txt = Entry(F2, width=8,textvariable=self.spirit, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=2,column=1,padx=5,pady=5)
        
        white_lac_lbl = Label(F2, text="White Lac (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=3,column=0,padx=5,pady=5,sticky="w")
        white_lac_txt = Entry(F2, width=8,textvariable=self.white, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=3,column=1,padx=5,pady=5)
        
        lac_pwd_lbl = Label(F2, text="Lac pwd (1 kg)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=4,column=0,padx=5,pady=5,sticky="w")
        lac_pwd_txt = Entry(F2, width=8,textvariable=self.lakh_pwd, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=4,column=1,padx=5,pady=5)
        
        chand_pwd_lbl = Label(F2, text="Chandrush pwd (1 kg)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=5,column=0,padx=5,pady=10,sticky="w")
        chand_pwd_txt = Entry(F2, width=8,textvariable=self.chandrush_pwd, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=5,column=1,padx=5,pady=5)
        
        rajan_lbl = Label(F2, text="Rajan/Rosin (1 kg)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=6,column=0,padx=5,pady=5,sticky="w")
        rajan_txt = Entry(F2, width=8,textvariable=self.rajan, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=6,column=1,padx=5,pady=5)
        
        thinner_lbl = Label(F2, text="Ameya Thinner (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=7,column=0,padx=5,pady=5,sticky="w")
        thinner_txt = Entry(F2, width=8,textvariable=self.thinner, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=7,column=1,padx=5,pady=5)
        
        #==========PACKETS AND PAPER==========#
        F3=LabelFrame(self.root, bd=10, relief=GROOVE, text="Paper & Packets", font=("times new roman", 15, "bold"), fg="gold", bg=bg_color)
        F3.place(x=360, y=180, width=355, height=405)
        
        #bath_lbl = Label(F2, text="Chandrush", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=0, column=1, padx=10,pady=10)
        #bath_txt = Entry(F2, width=10, font("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=0,column=1,padx=10,pady=10)
        
        alo100_lbl = Label(F3, text="Aloxide 80/100", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=0,column=0,padx=5,pady=5,sticky="w")
        alo100_txt = Entry(F3, width=6,textvariable=self.alo_80, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=0,column=1,padx=5,pady=5)
        
        alo120_lbl = Label(F3, text="Alo 120/150/180/220", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=1,column=0,padx=5,pady=5,sticky="w")
        alo120_txt = Entry(F3, width=6,textvariable=self.alo_120, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=1,column=1,padx=5,pady=5)
        
        sandpaper_lbl = Label(F3, text="Sandpaper (1pc)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=2,column=0,padx=5,pady=5,sticky="w")
        sandpaper_txt = Entry(F3, width=6,textvariable=self.sandpaper, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=2,column=1,padx=5,pady=5)
        
        roll_paper_lbl = Label(F3, text="Roll Paper (1m)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=3,column=0,padx=5,pady=5,sticky="w")
        roll_paper_txt = Entry(F3, width=6,textvariable=self.rollpaper, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=3,column=1,padx=5,pady=5)
        
        tukda_lbl = Label(F3, text="Brown Tukda", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=4,column=0,padx=5,pady=5,sticky="w")
        tukda_txt = Entry(F3, width=6,textvariable=self.tukda, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=4,column=1,padx=5,pady=5)
        
        amber_lbl = Label(F3, text="Amber/Ravsena/Bumsena", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=5,column=0,padx=5,pady=5,sticky="w")
        amber_txt = Entry(F3, width=6,textvariable=self.amber, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=5,column=1,padx=5,pady=5)
        
        kesari_lbl = Label(F3, text="Kesari/Mithi/Mahogany", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=6,column=0,padx=5,pady=5,sticky="w")
        kesari_txt = Entry(F3, width=6,textvariable=self.kesari, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=6,column=1,padx=5,pady=5)
        
        zinc_lbl = Label(F3, text="Zinc (100 gm)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=7,column=0,padx=5,pady=5,sticky="w")
        zinc_txt = Entry(F3, width=6,textvariable=self.zinc, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=7,column=1,padx=5,pady=5)
        
        #==========REST==========#
        F4=LabelFrame(self.root, bd=10, relief=GROOVE, text="Others", font=("times new roman", 15, "bold"), fg="gold", bg=bg_color)
        F4.place(x=720, y=180, width=345, height=405)
        
        #bath_lbl = Label(F2, text="Chandrush", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=0, column=1, padx=10,pady=10)
        #bath_txt = Entry(F2, width=10, font("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=0,column=1,padx=10,pady=10)
        
        dk_lbl = Label(F4, text="DK Thinner (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=0,column=0,padx=5,pady=5,sticky="w")
        dk_txt = Entry(F4, width=8,textvariable=self.dk, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=0,column=1,padx=5,pady=5)
        
        wood_matte_lbl = Label(F4, text="WoodPol Matte (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=1,column=0,padx=5,pady=5,sticky="w")
        wood_matte_txt = Entry(F4, width=8,textvariable=self.woodmatte, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=1,column=1,padx=5,pady=5)
        
        wood_glossy_lbl = Label(F4, text="WoodPol Glossy (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=2,column=0,padx=5,pady=5,sticky="w")
        wood_glossy_txt = Entry(F4, width=8,textvariable=self.woodglossy, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=2,column=1,padx=5,pady=5)
        
        sealer_lbl = Label(F4, text="Sealer (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=3,column=0,padx=5,pady=5,sticky="w")
        sealer_lac_txt = Entry(F4, width=8,textvariable=self.sealer, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=3,column=1,padx=5,pady=5)
        
        saree_lbl = Label(F4, text="Saree", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=4,column=0,padx=5,pady=5,sticky="w")
        saree_txt = Entry(F4, width=8,textvariable=self.saree, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=4,column=1,padx=5,pady=5)
        
        mom_plain_lbl = Label(F4, text="Mom plain", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=5,column=0,padx=5,pady=10,sticky="w")
        mom_plain_txt = Entry(F4, width=8,textvariable=self.momplain, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=5,column=1,padx=5,pady=5)
        
        mom_matte_lbl = Label(F4, text="Mom matte", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=6,column=0,padx=5,pady=5,sticky="w")
        mom_matte_txt = Entry(F4, width=8,textvariable=self.mommatte, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=6,column=1,padx=5,pady=5)
        
        brush_lbl = Label(F4, text="Dabba (ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=7,column=0,padx=5,pady=5,sticky="w")
        brush_txt = Entry(F4, width=8,textvariable=self.brush, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=7,column=1,padx=5,pady=5)
        
        
        #==========BILL AREA==========#
        F5=Frame(self.root,bd=10,relief=GROOVE)
        F5.place(x=1070, y=180, width=280, height=405)
        
        bill_title=Label(F5, text="Bill", font="arial 15 bold" ,bd=7,relief=GROOVE).pack(fill=X)
        scroll_y=Scrollbar(F5,orient=VERTICAL)
        self.txtarea=Text(F5,yscrollcommand=scroll_y.set)
        scroll_y.pack(side=RIGHT, fill=Y)
        scroll_y.config(command=self.txtarea.yview)
        self.txtarea.pack(fill=BOTH,expand=1)
        
        #==========BUTTON FRAME==========#
        F6=LabelFrame(self.root, bd=10, relief=GROOVE, text="Bill Menu", font=("times new roman", 15, "bold"), fg="gold", bg=bg_color)
        F6.place(x=0, y=590, relwidth=1, height=140)
        
        #m1=Label(F6, text="Total Price", bg=bg_color, fg="white", font=("times new roman",14,"bold")).grid(row=0,coumn=0,padx=20,pady=1,sticky="w")
        m1_lbl=Label(F6, text="Total Polish Price", bg=bg_color, fg="white" ,font=("times new roman",14,"bold")).grid(row=0,column=0,padx=20,pady=1,sticky="w")
        m1_txt = Entry(F6, width=18,textvariable=self.tot_polish, font=("times new roman",10,"bold"),bd=7,relief=SUNKEN).grid(row=0,column=1,padx=10,pady=1)
        
        m2_lbl=Label(F6, text="Total P&P Price", bg=bg_color, fg="white" ,font=("times new roman",14,"bold")).grid(row=1,column=0,padx=20,pady=1,sticky="w")
        m2_txt = Entry(F6, width=18,textvariable=self.tot_pp, font=("times new roman",10,"bold"),bd=7,relief=SUNKEN).grid(row=1,column=1,padx=10,pady=1)
        
        m3_lbl=Label(F6, text="Total Other Price", bg=bg_color, fg="white" ,font=("times new roman",14,"bold")).grid(row=2,column=0,padx=20,pady=1,sticky="w")
        m3_txt = Entry(F6, width=18,textvariable=self.tot_other, font=("times new roman",10,"bold"),bd=7,relief=SUNKEN).grid(row=2,column=1,padx=10,pady=1)
        
        t1_lbl=Label(F6, text="Polish Tax", bg=bg_color, fg="white" ,font=("times new roman",14,"bold")).grid(row=0,column=2,padx=20,pady=1,sticky="w")
        t1_txt = Entry(F6, width=18,textvariable=self.tax_polish, font=("times new roman",10,"bold"),bd=7,relief=SUNKEN).grid(row=0,column=3,padx=10,pady=1)
        
        t2_lbl=Label(F6, text="P&P Tax", bg=bg_color, fg="white" ,font=("times new roman",14,"bold")).grid(row=1,column=2,padx=20,pady=1,sticky="w")
        t2_txt = Entry(F6, width=18,textvariable=self.tax_pp, font=("times new roman",10,"bold"),bd=7,relief=SUNKEN).grid(row=1,column=3,padx=10,pady=1)
        
        t3_lbl=Label(F6, text="Other Tax", bg=bg_color, fg="white" ,font=("times new roman",14,"bold")).grid(row=2,column=2,padx=20,pady=1,sticky="w")
        t3_txt = Entry(F6, width=18,textvariable=self.tax_other, font=("times new roman",10,"bold"),bd=7,relief=SUNKEN).grid(row=2,column=3,padx=10,pady=1)
        
        btn_F = Frame(F6,bd=7,relief=GROOVE)
        btn_F.place(x=740, width=585, height=100)
        
        total_btn = Button(btn_F, command=self.total, text="TOTAL", bg="cadetblue", fg="white", pady=15, width=7, bd=5, font="arial 15 bold").grid(row=0,column=0,padx=7,pady=5)
        generate_bill_btn = Button(btn_F, command=self.bill_area, text="BILL", bg="cadetblue", fg="white", pady=15, width=7, bd=5, font="arial 15 bold").grid(row=0,column=1,padx=7,pady=5)
        clear_btn = Button(btn_F, text="CLEAR", command=self.clear_data, bg="cadetblue", fg="white", pady=15, width=7, bd=5, font="arial 15 bold").grid(row=0,column=2,padx=7,pady=5)
        exit_btn = Button(btn_F, text="EXIT", command=self.exit_app, bg="cadetblue", fg="white", pady=15, width=7, bd=5, font="arial 15 bold").grid(row=0,column=3,padx=7,pady=5)
        #stats_btn = Button(btn_f, text="STATS", bg="cadetblue", fg="white", pady=15, width=7, bd=5, font="arial 15 bold").grid(row=0,column=4,padx=7,pady=5))
        stats_btn = Button(btn_F, text="STATS", command=self.validate, bg="cadetblue", fg="white", pady=15, width=7, bd=5, font="arial 15 bold").grid(row=0,column=4,padx=7,pady=5)
        self.welcome_bill()
        
    def total(self):
        global daily_profit
        self.total_polish_price = float(
                    (self.lakh.get()*price["lakh"])+
                    (self.chandrush.get()*price["chandrush"])+
                    (self.spirit.get()*price["spirit"])+
                    (self.white.get()*price["white"])+
                    (self.lakh_pwd.get()*price["lakh_pwd"])+
                    (self.chandrush_pwd.get()*price["chandrush_pwd"])+
                    (self.rajan.get()*price["rajan"])+
                    (self.thinner.get()*price["thinner"])
        )
        self.tot_polish.set(str(self.total_polish_price))
        self.tax_one = round((self.total_polish_price)*0.05,2)
        self.tax_polish.set(str(self.tax_one))
        
        self.total_pp_price = float(
                    (self.alo_80.get()*price["alo_80"])+
                    (self.alo_120.get()*price["alo_120"])+
                    (self.sandpaper.get()*price["sandpaper"])+
                    (self.rollpaper.get()*price["rollpaper"])+
                    (self.tukda.get()*price["tukda"])+
                    (self.amber.get()*price["amber"])+
                    (self.kesari.get()*price["kesari"])+
                    (self.zinc.get()*price["zinc"])

        )
        self.tot_pp.set(str(self.total_pp_price))
        self.tax_two = round((self.total_pp_price)*0.05,2)
        self.tax_pp.set(str(self.tax_two))

        self.total_other_price = float(
                    (self.dk.get()*price["dk"])+
                    (self.woodmatte.get()*price["woodmatte"])+
                    (self.woodglossy.get()*price["woodglossy"])+
                    (self.sealer.get()*price["sealer"])+
                    (self.saree.get()*price["saree"])+
                    (self.momplain.get()*price["momplain"])+
                    (self.mommatte.get()*price["mommatte"])+
                    (self.brush.get()*price["brush"])
        )
        self.tot_other.set(str(self.total_other_price))
        self.tax_three = round((self.total_other_price)*0.05,2)
        self.tax_other.set(str(self.tax_three))
        
        self.total_bill = str(float(self.total_polish_price + self.total_pp_price + self.total_other_price + self.tax_one + self.tax_two + self.tax_three))
        
    def welcome_bill(self):
        self.txtarea.delete('1.0',END)
        self.txtarea.insert(END,"\tSUPREME TRADERS")
        self.txtarea.insert(END,f"\n Bill ID: {self.billno.get()}")
        self.txtarea.insert(END,f"\n Customer Name: {self.cust_name.get()}")
        self.txtarea.insert(END,f"\n Phone Number: {self.phone.get()}")
        self.txtarea.insert(END,"\n-----------------------------")
        self.txtarea.insert(END,"\n PRODUCT\t\tQTY\tPRICE")
        self.txtarea.insert(END,"\n-----------------------------")
        
    def bill_area(self):
        global price
        if self.cust_name.get()=="" or self.phone.get()=="":
            messagebox.showerror("Error","Customer details required")
        elif self.tot_polish.get()=="0.0" and self.tot_pp.get()=="0.0" and self.tot_other.get()=="0.0":
            messagebox.showerror("Error", "No product purchased")
        else:
            self.welcome_bill()
            cnt=0
            if self.lakh.get()!=0:
                self.txtarea.insert(END,f"\nLakh\t\t{self.lakh.get()}\t"+str(price["lakh"]))
                
            if self.chandrush.get()!=0:
                self.txtarea.insert(END,f"\nChandrush\t\t{self.chandrush.get()}\t"+str(price["chandrush"]))
                
            if self.spirit.get()!=0:
                self.txtarea.insert(END,f"\nSpirit\t\t{self.spirit.get()}\t"+str(price["spirit"]))
                
            if self.white.get()!=0:
                self.txtarea.insert(END,f"\nWhite\t\t{self.white.get()}\t"+str(price["white"]))
                
            if self.lakh_pwd.get()!=0:
                self.txtarea.insert(END,f"\nLakh Powder\t\t{self.lakh_pwd.get()}\t"+str(price["lakh_pwd"]))
                
            if self.chandrush_pwd.get()!=0:
                self.txtarea.insert(END,f"\nChandrush Powder\t\t{self.chandrush_pwd.get()}\t"+str(price["chandrush_pwd"]))
                
            if self.rajan.get()!=0:
                self.txtarea.insert(END,f"\nRajan\t\t{self.rajan.get()}\t"+str(price["rajan"]))
                
            if self.thinner.get()!=0:
                self.txtarea.insert(END,f"\nThinner\t\t{self.thinner.get()}\t"+str(price["thinner"]))
                
            if self.alo_80.get()!=0:
                self.txtarea.insert(END,f"\nAlox. 80/100\t\t{self.alo_80.get()}\t"+str(price["alo_80"]))
                
            if self.alo_120.get()!=0:
                self.txtarea.insert(END,f"\nAlox. 120-220\t\t{self.alo_120.get()}\t"+str(price["alo_120"]))
                
            if self.sandpaper.get()!=0:
                self.txtarea.insert(END,f"\nSandpaper\t\t{self.sandpaper.get()}\t"+str(price["sandpaper"]))
                
            if self.rollpaper.get()!=0:
                self.txtarea.insert(END,f"\nRoll Paper\t\t{self.rollpaper.get()}\t"+str(price["rollpaper"]))
                
            if self.tukda.get()!=0:
                self.txtarea.insert(END,f"\nTukda\t\t{self.tukda.get()}\t"+str(price["tukda"]))
                
            if self.amber.get()!=0:
                self.txtarea.insert(END,f"\nAmber\t\t{self.amber.get()}\t"+str(price["amber"]))
                
            if self.kesari.get()!=0:
                self.txtarea.insert(END,f"\nKesari\t\t{self.kesari.get()}\t"+str(price["kesari"]))
                
            if self.zinc.get()!=0:
                self.txtarea.insert(END,f"\nZinc\t\t{self.zinc.get()}\t"+str(price["zinc"]))
                
            if self.dk.get()!=0:
                self.txtarea.insert(END,f"\nDK Lac Thinner\t\t{self.dk.get()}\t"+str(price["dk"]))
                
            if self.woodmatte.get()!=0:
                self.txtarea.insert(END,f"\nWoodPol Matte\t\t{self.woodmatte.get()}\t"+str(price["woodmatte"]))
                
            if self.woodglossy.get()!=0:
                self.txtarea.insert(END,f"\nWoodPol Glossy\t\t{self.woodglossy.get()}\t"+str(price["woodglossy"]))
                
            if self.sealer.get()!=0:
                self.txtarea.insert(END,f"\nSealer\t\t{self.sealer.get()}\t"+str(price["sealer"]))
                
            if self.saree.get()!=0:
                self.txtarea.insert(END,f"\nSaree\t\t{self.saree.get()}\t"+str(price["saree"]))
                
            if self.momplain.get()!=0:
                self.txtarea.insert(END,f"\nMom Plain\t\t{self.momplain.get()}\t"+str(price["momplain"]))
                
            if self.mommatte.get()!=0:
                self.txtarea.insert(END,f"\nMom Matte\t\t{self.mommatte.get()}\t"+str(price["mommatte"]))
                
            if self.brush.get()!=0:
                self.txtarea.insert(END,f"\nBrush\t\t{self.brush.get()}\t"+str(price["brush"]))
                
            self.txtarea.insert(END,"\n-----------------------------")
            self.txtarea.insert(END,f"\nPolish Tax: \t\t\t{self.tax_polish.get()}")
            self.txtarea.insert(END,f"\nP&P Tax: \t\t\t{self.tax_pp.get()}")
            self.txtarea.insert(END,f"\nOther Tax: \t\t\t{self.tax_other.get()}")
            self.txtarea.insert(END,"\n-----------------------------")
            self.txtarea.insert(END,f"\nTotal Bill: \t\t Rs. {self.total_bill}")
            self.save_bill()
    
    def save_bill(self):
        global quantity_day
        global quantity
        op = messagebox.askyesno("Save Bill","Do you want to save the bill")
        global daily_profit
        if(op>0):
            self.bill_data=self.txtarea.get("1.0",END)
            f1=open("bills/"+str(self.billno.get())+".txt","w")
            f1.write(self.bill_data)
            f1.close()
            messagebox.showinfo("Saved",f"Bill ID {self.billno.get()} saved succesfully!")
            
            quantity_day = {}
            count=0
            with open("bills/quantity_day.txt") as fo:
                for rec in fo:
                    quantity_day[products[count]] = float(rec.split(",")[0])
                    count +=1
            #print("Initial quantity_day")
            #print(quantity_day)
            
            total_stock = {}
            count=0
            with open("bills/stock_total.txt") as fo:
                for rec in fo:
                    total_stock[products[count]] = float(rec.split(",")[0])
                    count +=1
            
#             if self.lakh.get()!=0:
            quantity["lakh"] = self.lakh.get()
#             if self.chandrush.get()!=0:
            quantity["chandrush"] = self.chandrush.get()
#             if self.spirit.get()!=0:
            quantity["spirit"] = self.spirit.get()
#             if self.white.get()!=0:
            quantity["white"] = self.white.get()
#             if self.lakh_pwd.get()!=0:
            quantity["lakh_pwd"] = self.lakh_pwd.get()
#             if self.chandrush_pwd.get()!=0:
            quantity["chandrush_pwd"] = self.chandrush_pwd.get()
#             if self.rajan.get()!=0:
            quantity["rajan"] = self.rajan.get()
#             if self.thinner.get()!=0:
            quantity["thinner"] = self.thinner.get()
#             if self.alo_80.get()!=0:
            quantity["alo_80"] = self.alo_80.get()
#             if self.alo_120.get()!=0:
            quantity["alo_120"] = self.alo_120.get()
#             if self.sandpaper.get()!=0:
            quantity["sandpaper"] = self.sandpaper.get()
#             if self.rollpaper.get()!=0:
            quantity["rollpaper"] = self.rollpaper.get()
#             if self.tukda.get()!=0:
            quantity["tukda"] = self.tukda.get()
#             if self.amber.get()!=0:
            quantity["amber"] = self.amber.get()
#             if self.kesari.get()!=0:
            quantity["kesari"] = self.kesari.get()
#             if self.zinc.get()!=0:
            quantity["zinc"] = self.zinc.get()
#             if self.dk.get()!=0:
            quantity["dk"] = self.dk.get()
#             if self.woodmatte.get()!=0:
            quantity["woodmatte"] = self.woodmatte.get()
#             if self.woodglossy.get()!=0:
            quantity["woodglossy"] = self.woodglossy.get()
#             if self.sealer.get()!=0:
            quantity["sealer"] = self.sealer.get()
#             if self.saree.get()!=0:
            quantity["saree"] = self.saree.get()
#             if self.momplain.get()!=0:
            quantity["momplain"] = self.momplain.get()
#             if self.mommatte.get()!=0:
            quantity["mommatte"] = self.mommatte.get()
#             if self.brush.get()!=0:
            quantity["brush"] = self.brush.get()
    
            for i in range(len(products)):
                t = products[i]
                total_stock[t] -= round(quantity[t],2)
            
            temp=total_stock["lakh"]
            f1=open("bills/stock_total.txt","w")
            f1.write(str(temp)+",\n")
            f1.close()
            
            f1=open("bills/stock_total.txt","a")
            for i in range(len(products)-1):
                temp = total_stock[products[i+1]]
                f1.write(str(temp)+",\n")
            f1.close()

            total_stock = {}
            count=0
            with open("bills/cost.txt") as fo:
                for rec in fo:
                    total_stock[products[count]] = float(rec.split(",")[0])
                    count +=1
            
            #print("quantity:\n")
            #print(quantity)
#             print("quantity_day:\n")
#             print(quantity_day)
            
            quantity_sum = {}
            for i in range(len(products)):
                quantity_sum[products[i]] = quantity_day[products[i]]+quantity[products[i]]
            quantity_day = quantity_sum
#             print("New quantity_day: ")
#             print(quantity_day)
            
            temp=quantity_day["lakh"]
            f1=open("bills/quantity_day.txt","w")
            f1.write(str(temp)+",\n")
            f1.close()
            
            f1=open("bills/quantity_day.txt","a")
            for i in range(len(products)-1):
                temp = quantity_day[products[i+1]]
                f1.write(str(temp)+",\n")
            f1.close()
            
#             f1 = open("bills/quantity_day.txt","w") 
#             f1.write(f"{quantity_day["lakh"]+quantity["lakh"]},\n")
#             f1.close()
#             f1 = open("bills/quantity_day.txt","a")

#             f1.write(f"{float(quantity_day["chandrush"]+float(quantity["chandrush"])},\n")
#             f1.write(f"{quantity_day["spirit"]+quantity["spirit"]},\n")
#             f1.write(f"{quantity_day["white"]+quantity["white"]},\n")
#             f1.write(f"{quantity_day["lakh_pwd"]+quantity["lakh_pwd"]},\n")
#             f1.write(f"{quantity_day["chandrush_pwd"]+quantity["chandrush_pwd"]},\n")
#             f1.write(f"{quantity_day["rajan"]+quantity["rajan"]},\n")
#             f1.write(f"{quantity_day["thinner"]+quantity["thinner"]},\n")
#             f1.write(f"{quantity_day["alo_80"]+quantity["alo_80"]},\n")
#             f1.write(f"{quantity_day["alo_120"]+quantity["alo_120"]},\n")
#             f1.write(f"{quantity_day["sandpaper"]+quantity["sandpaper"]},\n")
#             f1.write(f"{quantity_day["rollpaper"]+quantity["rollpaper"]},\n")
#             f1.write(f"{quantity_day["tukda"]+quantity["tukda"]},\n")
#             f1.write(f"{quantity_day["amber"]+quantity["amber"]},\n")
#             f1.write(f"{quantity_day["kesari"]+quantity["kesari"]},\n")
#             f1.write(f"{quantity_day["zinc"]+quantity["zinc"]},\n")
#             f1.write(f"{quantity_day["dk"]+quantity["dk"]},\n")
#             f1.write(f"{quantity_day["woodmatte"]+quantity["woodmatte"]},\n")
#             f1.write(f"{quantity_day["woodglossy"]+quantity["woodglossy"]},\n")
#             f1.write(f"{quantity_day["sealer"]+quantity["sealer"]},\n")
#             f1.write(f"{quantity_day["saree"]+quantity["saree"]},\n")
#             f1.write(f"{quantity_day["momplain"]+quantity["momplain"]},\n")
#             f1.write(f"{quantity_day["mommatte"]+quantity["mommatte"]},\n")
#             f1.write(f"{quantity_day["brush"]+quantity["brush"]},\n")
#             f1.close()
            
            quantity_day = {}
            count=0
            with open("bills/quantity_day.txt") as fo:
                for rec in fo:
                    quantity_day[products[count]] = float(rec.split(",")[0])
                    count +=1
            
            
            #daily_profit += float(self.total_polish_price + self.total_pp_price + self.total_other_price)
            #print(quantity_day)
            #print(daily_profit)
        else:
            return
        
    def find_bill(self):
        pass
#         present="no"
#         for i in os.listdir("bills/"):
#             if i.split('.')[0] == self.search_bill.get():
#                 f1=open(f"bills/{i},"r")
#                 self.txtarea.delete("1.0",END)
#                 for d in f1:
#                     self.txtarea.insert(END,d)
#                 f1.close()
#                 present="yes"
#         if present="no":
#             messagebox.showerror("Error","Bill ID not found")
    
    def clear_data(self):
        op=messagebox.askyesno("Clear","Do you want to clear the bill?")
        if(int(op)>0):
            #CUSTOMER#
            self.cust_name.set("")
            self.phone.set("")
            self.billno.set("")
            x = random.randint(1000,9999)
            self.billno.set(str(x))
            self.search_bill.set("")

            #POLISH#
            self.lakh.set(0)
            self.chandrush.set(0)
            self.spirit.set(0)
            self.white.set(0)
            self.lakh_pwd.set(0)
            self.chandrush_pwd.set(0)
            self.rajan.set(0)
            self.thinner.set(0)

            #P&P#
            self.alo_80.set(0)
            self.alo_120.set(0)
            self.sandpaper.set(0)
            self.rollpaper.set(0)
            self.tukda.set(0)
            self.amber.set(0)
            self.kesari.set(0)
            self.zinc.set(0)

            #OTHERS#
            self.dk.set(0)
            self.woodmatte.set(0)
            self.woodglossy.set(0)
            self.sealer.set(0)
            self.saree.set(0)
            self.momplain.set(0)
            self.mommatte.set(0)
            self.brush.set(0)

            #TOTAL & TAX#
            self.tot_polish.set(0)
            self.tot_pp.set(0)
            self.tot_other.set(0)
            self.tax_polish.set(0)
            self.tax_pp.set(0)
            self.tax_other.set(0)
            #self.total_bill.set("")

            self.welcome_bill()
        
    def validate(self):
        answer = simpledialog.askstring("Password", "Enter password:", show='*')
#         print(self.password.get())
#         print(answer)
        if(answer==self.password.get()):
            self.new_window(Stats)
        else:
            messagebox.showerror("Error", "Wrong Password")
            
    def new_window(self, _class):
        self.new = Toplevel(self.root)
        _class(self.new)
    
    def exit_app(self):
        op=messagebox.askyesno("Exit","Do you want to exit the app?")
        if(op>0):
            self.root.destroy()
            
    def change_screen(self):
        pass
        
class Stats:
    def __init__(self, root):
        global daily_profit
        global monthly_profit
        global quantity_day
        global stock
        global daily
        global total_stock
        global profit_curr
        global products
        self.root=root
        self.root.geometry("1350x750+0+0")
        self.root.title("New Window!")
        bg_color = "#074463"
        title = Label(self.root, text="SUPREME TRADERS", bd=12, relief=GROOVE, bg=bg_color, fg="white", font=("times new roman", 30,"bold"), pady=2).pack(fill=X)
        
        #=========VARIABLE==========#
        
        OPTIONS = ["Daily", "Weekly", "Monthly"]
        self.time_period = IntVar()
        self.time_period.set(OPTIONS[0]) #Deafult value.
        
        #==========Stats Menu==========#
        F9=LabelFrame(self.root, bd=10, relief=GROOVE, text="", font=("times new roman", 15, "bold"), fg="gold", bg=bg_color)
        F9.place(x=0, y=75, relwidth=1)
        
        #Drop down menu#
#         time_lbl = Label(F9, text="Select Timeframe: ", bg=bg_color, fg="white", font=("times new roman", 15, "bold")).grid(row=0, column=0, padx=20, pady=5)
#         opt = OptionMenu(F9, self.time_period, *OPTIONS)
#         opt.grid(row=0, column=1, padx=20, pady=5)
#         opt.config(width=20, font=('times new roman', 14, "bold"), bg=bg_color, fg="white")
        
        F8 = LabelFrame(self.root, bd=10, relief=GROOVE, text="", font=("times new roman", 15, "bold"), fg="gold", bg=bg_color)
        F8.place(x=0, y=140, relwidth=0.7)
        
        product_lbl = Label(F9, text="PRODUCT  ", bg=bg_color, fg="white", font=("times new roman", 15, "bold")).grid(row=0, column=0, padx=10, pady=5)
        qty_lbl = Label(F9, text="QUANTITY ", bg=bg_color, fg="white", font=("times new roman", 15, "bold")).grid(row=0, column=1, padx=10, pady=5)
        selling_price_lbl = Label(F9, text="SELLING PRICE", bg=bg_color, fg="white", font=("times new roman", 15, "bold")).grid(row=0, column=2, padx=10, pady=5)
        costing_price_lbl = Label(F9, text="COST PRICE", bg=bg_color, fg="white", font=("times new roman", 15, "bold")).grid(row=0, column=3, padx=10, pady=5)
        profit_lbl = Label(F9, text="PROFIT\t", bg=bg_color, fg="white", font=("times new roman", 15, "bold")).grid(row=0, column=4, padx=10, pady=5)
        stock_lbl = Label(F9, text="STOCK", bg=bg_color, fg="white", font=("times new roman", 15, "bold")).grid(row=0, column=5, padx=10, pady=5)
        
        price = {}
        count=0
        with open("bills/price.txt") as fo:
            for rec in fo:
                price[products[count]] = float(rec.split(",")[0])
                count +=1

        cost = {}
        count=0
        with open("bills/cost.txt") as fo:
            for rec in fo:
                cost[products[count]] = float(rec.split(",")[0])
                count +=1
       
        quantity_day = {}
        count=0
        with open("bills/quantity_day.txt") as fo:
            for rec in fo:
                quantity_day[products[count]] = float(rec.split(",")[0])
                count +=1
                
        total_stock = {}
        count=0
        with open("bills/stock_total.txt") as fo:
            for rec in fo:
                total_stock[products[count]] = float(rec.split(",")[0])
                count +=1
                
        profit_curr = {}
        for i in range(len(products)):
            t = products[i]
            profit_curr[t] = quantity_day[t]*(price[t]-cost[t])
        
        for i in range(len(products)):
            daily_profit += profit_curr[products[i]]
        
        
        for i in range(len(products)):
            #label = Label(F8, text=f"{i}\t", bg=bg_color, fg="white", font=("times new roman", 10, "bold")).grid(row=i, column=0, padx=10, pady=1))
            self.var = StringVar()
            self.var.set(products[i])
            pr_lbl = Label(F8, text=f"{self.var.get()}\t", bg=bg_color, fg="lightgreen", font=("times new roman", 7, "bold")).grid(row=i, column=0, padx=30, pady=0)
            prq_lbl = Label(F8, text=f"{quantity_day[products[i]]}\t", relief=RIDGE, bg=bg_color, fg="white", font=("times new roman", 7, "bold")).grid(row=i, column=1, padx=30, pady=0)
            prp_lbl = Label(F8, text=f"{price[products[i]]}\t", relief=RIDGE, bg=bg_color, fg="white", font=("times new roman", 7, "bold")).grid(row=i, column=2, padx=100, pady=0)
            prc_lbl = Label(F8, text=f"{cost[products[i]]}\t", relief=RIDGE, bg=bg_color, fg="white", font=("times new roman", 7, "bold")).grid(row=i, column=3, padx=20, pady=0)
            prof_lbl = Label(F8, text=f"{profit_curr[products[i]]}\t", relief=RIDGE, bg=bg_color, fg="white", font=("times new roman", 7, "bold")).grid(row=i, column=4, padx=30, pady=0)
            stock_lbl = Label(F8, text=f"{total_stock[products[i]]}\t", relief=RIDGE, bg=bg_color, fg="white", font=("times new roman", 7, "bold")).grid(row=i, column=5, padx=30, pady=0)
        
#         lakh_lbl = Label(F8, text="Lac (1 ltr)", font=("times new roman",10,"bold"), bg=bg_color, fg="lightgreen").grid(row=1,column=0,padx=5,pady=0,sticky="w")
#         #lakh_qty = Label(F8, text=f"{qauntity["lakh"]}", font=("times new roman",12,"bold"), bg=bg_color, fg="lightgreen").grid(row=0,column=0,padx=5,pady=5,sticky="w")
#         chandrush_lbl = Label(F8, text="Chandrush (1 ltr)", font=("times new roman",10,"bold"), bg=bg_color, fg="lightgreen").grid(row=2,column=0,padx=5,pady=0,sticky="w")
#         spirit_lbl = Label(F8, text="Spirit (1 ltr)", font=("times new roman",10,"bold"), bg=bg_color, fg="lightgreen").grid(row=3,column=0,padx=5,pady=0,sticky="w")
#         white_lbl = Label(F8, text="White (1 ltr)", font=("times new roman",10,"bold"), bg=bg_color, fg="lightgreen").grid(row=4,column=0,padx=5,pady=0,sticky="w")
#         lakh_pwd_lbl = Label(F8, text="Lac pwd", font=("times new roman",10,"bold"), bg=bg_color, fg="lightgreen").grid(row=5,column=0,padx=5,pady=0,sticky="w")
#         chandrush_pwd_lbl = Label(F8, text="Chandrush pwd", font=("times new roman",10,"bold"), bg=bg_color, fg="lightgreen").grid(row=6,column=0,padx=5,pady=0,sticky="w")
#         rajan_lbl = Label(F8, text="Rajan", font=("times new roman",10,"bold"), bg=bg_color, fg="lightgreen").grid(row=7,column=0,padx=5,pady=0,sticky="w")
#         thinner_lbl = Label(F8, text="Thinner", font=("times new roman",10,"bold"), bg=bg_color, fg="lightgreen").grid(row=8,column=0,padx=5,pady=0,sticky="w")
#         alo_80_lbl = Label(F8, text="Alo 80/100", font=("times new roman",10,"bold"), bg=bg_color, fg="lightgreen").grid(row=9,column=0,padx=5,pady=0,sticky="w")
#         alo_120_lbl = Label(F8, text="Alo 120-220", font=("times new roman",10,"bold"), bg=bg_color, fg="lightgreen").grid(row=10,column=0,padx=5,pady=0,sticky="w")
#         sandpaper_lbl = Label(F8, text="sandpaper", font=("times new roman",10,"bold"), bg=bg_color, fg="lightgreen").grid(row=11,column=0,padx=5,pady=0,sticky="w")
#         rollpaper_lbl = Label(F8, text="rollpaper", font=("times new roman",10,"bold"), bg=bg_color, fg="lightgreen").grid(row=12,column=0,padx=5,pady=0,sticky="w")
#         amber_lbl = Label(F8, text="amber", font=("times new roman",10,"bold"), bg=bg_color, fg="lightgreen").grid(row=14,column=0,padx=5,pady=0,sticky="w")
#         kesari_lbl = Label(F8, text="kesari", font=("times new roman",10,"bold"), bg=bg_color, fg="lightgreen").grid(row=15,column=0,padx=5,pady=0,sticky="w")
#         zinc_lbl = Label(F8, text="Zinc", font=("times new roman",10,"bold"), bg=bg_color, fg="lightgreen").grid(row=16,column=0,padx=5,pady=0,sticky="w")
#         tukda_lbl = Label(F8, text="Tukda", font=("times new roman",10,"bold"), bg=bg_color, fg="lightgreen").grid(row=13,column=0,padx=5,pady=0,sticky="w")
#         dk_lbl = Label(F8, text="dk", font=("times new roman",10,"bold"), bg=bg_color, fg="lightgreen").grid(row=17,column=0,padx=5,pady=0,sticky="w")
#         woodmatte_lbl = Label(F8, text="woodmatte", font=("times new roman",10,"bold"), bg=bg_color, fg="lightgreen").grid(row=18,column=0,padx=5,pady=0,sticky="w")
#         woodglossy_lbl = Label(F8, text="woodglossy", font=("times new roman",10,"bold"), bg=bg_color, fg="lightgreen").grid(row=19,column=0,padx=5,pady=0,sticky="w")
#         sealer_lbl = Label(F8, text="sealer", font=("times new roman",10,"bold"), bg=bg_color, fg="lightgreen").grid(row=20,column=0,padx=5,pady=0,sticky="w")
#         saree_lbl = Label(F8, text="saree", font=("times new roman",10,"bold"), bg=bg_color, fg="lightgreen").grid(row=21,column=0,padx=5,pady=0,sticky="w")
#         momplain_lbl = Label(F8, text="momplain", font=("times new roman",10,"bold"), bg=bg_color, fg="lightgreen").grid(row=22,column=0,padx=5,pady=0,sticky="w")
#         mommatte_lbl = Label(F8, text="mommatte", font=("times new roman",10,"bold"), bg=bg_color, fg="lightgreen").grid(row=23,column=0,padx=5,pady=0,sticky="w")
#         brush_lbl = Label(F8, text="brush", font=("times new roman",10,"bold"), bg=bg_color, fg="lightgreen").grid(row=24,column=0,padx=5,pady=0,sticky="w")
#         #lakh_lbl = Label(F8, text="Lac (1 ltr)", font=("times new roman",12,"bold"), bg=bg_color, fg="lightgreen").grid(row=1,column=0,padx=5,pady=1,sticky="w")
        

#         lst = [("",0,0,0,0)]
#         for i in price:
#             lst.append((i, quantity[i], price[i]*quantity[i], cost[i]*quantity[i], (price[i]-cost[i])*quantity[i]))
        
#         for i in lst:
        
        
#         for row in range(5):
#             for column in range(6):
#                 self.e = Label(F8, "Row "+str(row)+", Column "+str(column))
#                 self.e.grid(row=row, column=column)
            
            
             
        
        #UNDER THE SCREEN BUTTONS#
        F7 = LabelFrame(self.root, bd=10, relief=GROOVE, text="Total Profits", font=("times new roman", 15, "bold"), fg="gold", bg=bg_color)
        F7.place(x=0, y=595, relwidth=1, height=140)
        
        #Variables#
        self.profit_day = DoubleVar()
        self.profit_month = DoubleVar()
        self.total_prof = DoubleVar()
        
        self.profit_day.set(daily_profit)
        self.profit_month.set(monthly_profit)
        self.total_prof.set(total_profit)
        
        m1_lbl=Label(F7, text="Daily Profit", bg=bg_color, fg="white" ,font=("times new roman",14,"bold")).grid(row=0,column=0,padx=20,pady=2,sticky="w")
        m1_txt = Entry(F7, width=18,textvariable=self.profit_day, font=("times new roman",10,"bold"),bd=7,relief=SUNKEN).grid(row=0,column=1,padx=10,pady=1)
        #m1_lbl=Label(F7, text=f"{daily_profit}", bg=bg_color, fg="white" ,font=("times new roman",14,"bold")).grid(row=0,column=1,padx=20,pady=2,sticky="w")
        m2_lbl=Label(F7, text="Total Profit", bg=bg_color, fg="white" ,font=("times new roman",14,"bold")).grid(row=2,column=0,padx=20,pady=2,sticky="w")
        m2_txt = Entry(F7, width=18,textvariable=self.total_prof, font=("times new roman",10,"bold"),bd=7,relief=SUNKEN).grid(row=2,column=1,padx=10,pady=1)
        
        m3_lbl=Label(F7, text="Monthly Profit", bg=bg_color, fg="white" ,font=("times new roman",14,"bold")).grid(row=1,column=0,padx=20,pady=2,sticky="w")
        m3_txt = Entry(F7, width=18,textvariable=self.profit_month, font=("times new roman",10,"bold"),bd=7,relief=SUNKEN).grid(row=1,column=1,padx=10,pady=1)
        
        price_btn=Button(F7, command=self.validate_price, text="Change Prices",width=20, bd=7, font="arial 12 bold")
        price_btn.place(x=490, y=4)
        cost_btn=Button(F7, command=self.validate_cost, text="Change Costs", width=20, bd=7, font="arial 12 bold")
        cost_btn.place(x=490, y=54)
        
        
        #Side Screen#
        F10 = LabelFrame(self.root, bd=10, relief=GROOVE)
        F10.place(x=0.7*1350+5, y=145, relwidth=0.3, height=450)
        
        #Buttons#
        btn_F = Frame(F7,bd=7,relief=GROOVE)
        btn_F.place(x=740, y=3, width=585, height=90)
        
        stock_btn = Button(btn_F, text="STOCK",command=self.validate_stock, bg="cadetblue", fg="white", pady=10, width=7, bd=5, font="arial 15 bold").grid(row=0,column=0,padx=5,pady=1)
        end_day_btn = Button(btn_F, text="END DAY", command =self.day_over ,bg="cadetblue", fg="white", pady=10, width=7, bd=5, font="arial 15 bold").grid(row=0,column=1,padx=5,pady=1)
        clear_btn = Button(btn_F, text="CLEAR", bg="cadetblue", fg="white", pady=10, width=7, bd=5, font="arial 15 bold").grid(row=0,column=2,padx=5,pady=1)
        exit_btn = Button(btn_F, text="EXIT", command=self.exit_app, bg="cadetblue", fg="white", pady=10, width=7, bd=5, font="arial 15 bold").grid(row=0,column=3,padx=5,pady=1)
        #stats_btn = Button(btn_f, text="STATS", bg="cadetblue", fg="white", pady=15, width=7, bd=5, font="arial 15 bold").grid(row=0,column=4,padx=7,pady=5))
        analyse_btn = Button(btn_F, text="ANALYSIS", bg="cadetblue", fg="white", pady=10, width=8, bd=5, font="arial 15 bold").grid(row=0,column=4,padx=5,pady=1)
        
    def day_over(self):
        global total_profit
        global monthly_profit
        global daily_profit
        global quantity_day
        global quantity_month
        op = messagebox.askyesno("End Day", "Do you want to end day?")
        if(op>0):
            total_profit += daily_profit
            monthly_profit += daily_profit
            #daily.loc[len(daily.index)] = [date.today(), 0, 0, daily_profit]
            #daily.to_excel('accounts.xlsx')
            
            f1=open("bills/daily_profit.txt","a")
            f1.write(f"{date.today()} --> "+str(daily_profit)+"\tmonthly profit = "+str(monthly_profit)+"\n")
            f1.close()
            for i in quantity_day:
                quantity_month[i] += quantity_day[i]
                quantity_day[i] = 0.0
            
            temp=quantity_day["lakh"]
            f1=open("bills/quantity_day.txt","w")
            f1.write(str(temp)+",\n")
            f1.close()
            
            f1=open("bills/quantity_day.txt","a")
            for i in range(len(products)-1):
                temp = quantity_day[products[i+1]]
                f1.write(str(temp)+",\n")
            f1.close()
            
            quantity_day = {}
            count=0
            with open("bills/quantity_day.txt") as fo:
                for rec in fo:
                    quantity_day[products[count]] = float(rec.split(",")[0])
                    count +=1
            
            temp=quantity_month["lakh"]
            f1=open("bills/quantity_month.txt","w")
            f1.write(str(temp)+",\n")
            f1.close()
            
            f1=open("bills/quantity_month.txt","a")
            for i in range(len(products)-1):
                temp = quantity_month[products[i+1]]
                f1.write(str(temp)+",\n")
            f1.close()
            
            daily_profit = 0.0
        else:
            return
    
    def update_stock(self):
        pass
    
    def exit_app(self):
        op=messagebox.askyesno("Exit","Do you want to exit the app?")
        if(op>0):
            self.root.destroy()
    
    def change_prices(self, _class):
        self.new = Toplevel(self.root)
        _class(self.new)
        
    def change_costs(self, _class):
        self.new = Toplevel(self.root)
        _class(self.new)
        
    def change_stock(self, _class):
        self.new = Toplevel(self.root)
        _class(self.new)
    
    def validate_price(self):
        op=messagebox.askyesno("Change Prices","Do you want to change prices?")
        if(op>0):
            self.change_prices(price_window)
            
    def validate_cost(self):
        op=messagebox.askyesno("Change Costs","Do you want to change costs?")
        if(op>0):
            self.change_costs(cost_window)
            
    def validate_stock(self):
        op=messagebox.askyesno("Add Stock","Do you want to add stock?")
        if(op>0):
            self.change_prices(stock_window)
    
    
        
class price_window:
    def __init__ (self, root):
        global price
        self.root=root
        self.root.geometry("1350x750+0+0")
        self.root.title("New Window!")
        bg_color = "#074463"
        title = Label(self.root, text="ENTER NEW SELLING PRICES", bd=12, relief=GROOVE, bg=bg_color, fg="white", font=("times new roman", 30,"bold"), pady=2).pack(fill=X)
        
        #POLISH#
        self.lakh = DoubleVar()
        self.chandrush = DoubleVar()
        self.spirit = DoubleVar()
        self.white = DoubleVar()
        self.lakh_pwd = DoubleVar()
        self.chandrush_pwd = DoubleVar()
        self.rajan = DoubleVar()
        self.thinner = DoubleVar()
        
        #P&P#
        self.alo_80 = DoubleVar()
        self.alo_120 = DoubleVar()
        self.sandpaper = DoubleVar()
        self.rollpaper = DoubleVar()
        self.tukda = DoubleVar()
        self.amber = DoubleVar()
        self.kesari = DoubleVar()
        self.zinc = DoubleVar()
        
        #OTHERS#
        self.dk = DoubleVar()
        self.woodmatte = DoubleVar()
        self.woodglossy = DoubleVar()
        self.sealer = DoubleVar()
        self.saree = DoubleVar()
        self.momplain = DoubleVar()
        self.mommatte = DoubleVar()
        self.brush = DoubleVar()
        
        #Set as original#
        #POLISH#
        self.lakh.set(price["lakh"])
        self.chandrush.set(price["chandrush"])
        self.spirit.set(price["spirit"])
        self.white.set(price["white"])
        self.lakh_pwd.set(price["lakh_pwd"])
        self.chandrush_pwd.set(price["chandrush_pwd"])
        self.rajan.set(price["rajan"])
        self.thinner.set(price["thinner"])

        #P&P#
        self.alo_80.set(price["alo_80"])
        self.alo_120.set(price["alo_120"])
        self.sandpaper.set(price["sandpaper"])
        self.rollpaper.set(price["rollpaper"])
        self.tukda.set(price["tukda"])
        self.amber.set(price["amber"])
        self.kesari.set(price["kesari"])
        self.zinc.set(price["zinc"])

        #OTHERS#
        self.dk.set(price["dk"])
        self.woodmatte.set(price["woodmatte"])
        self.woodglossy.set(price["woodglossy"])
        self.sealer.set(price["sealer"])
        self.saree.set(price["saree"])
        self.momplain.set(price["momplain"])
        self.mommatte.set(price["mommatte"])
        self.brush.set(price["brush"])
        
        
        #==========COSMETIC FRAME==========#
        F12=LabelFrame(self.root, bd=10, relief=GROOVE, text="Polish", font=("times new roman", 15, "bold"), fg="gold", bg=bg_color)
        F12.place(x=155, y=180, width=350, height=405)
        
        #bath_lbl = Label(F2, text="Chandrush", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=0, column=1, padx=10,pady=10)
        #bath_txt = Entry(F2, width=10, font("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=0,column=1,padx=10,pady=10)
        
        lakh_lbl = Label(F12, text="Lac Polish (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=0,column=0,padx=5,pady=5,sticky="w")
        lakh_txt = Entry(F12, width=8, textvariable=self.lakh, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=0,column=1,padx=5,pady=5)
#         price["lakh"] = self.lakh.get()
        
        chandrush_lbl = Label(F12, text="Chandrush (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=1,column=0,padx=5,pady=5,sticky="w")
        chandrush_txt = Entry(F12, width=8,textvariable=self.chandrush, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=1,column=1,padx=5,pady=5)
#         price["chandrush"] = self.chandrush.get()
        
        spirit_lbl = Label(F12, text="Spirit (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=2,column=0,padx=5,pady=5,sticky="w")
        spirit_txt = Entry(F12, width=8,textvariable=self.spirit, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=2,column=1,padx=5,pady=5)
#         price["spirit"] = self.spirit.get()
        
        white_lac_lbl = Label(F12, text="White Lac (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=3,column=0,padx=5,pady=5,sticky="w")
        white_lac_txt = Entry(F12, width=8,textvariable=self.white, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=3,column=1,padx=5,pady=5)
#         price["white"] = self.white.get()
        
        lac_pwd_lbl = Label(F12, text="Lac pwd (1 kg)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=4,column=0,padx=5,pady=5,sticky="w")
        lac_pwd_txt = Entry(F12, width=8,textvariable=self.lakh_pwd, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=4,column=1,padx=5,pady=5)
#         price["lakh_pwd"] = self.lakh_pwd.get()
        
        chand_pwd_lbl = Label(F12, text="Chandrush pwd (1 kg)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=5,column=0,padx=5,pady=10,sticky="w")
        chand_pwd_txt = Entry(F12, width=8,textvariable=self.chandrush_pwd, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=5,column=1,padx=5,pady=5)
#         price["chandrush_pwd"] = self.chandrush_pwd.get()
        
        rajan_lbl = Label(F12, text="Rajan/Rosin (1 kg)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=6,column=0,padx=5,pady=5,sticky="w")
        rajan_txt = Entry(F12, width=8,textvariable=self.rajan, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=6,column=1,padx=5,pady=5)
#         price["rajan"] = self.rajan.get()
        
        thinner_lbl = Label(F12, text="Ameya Thinner (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=7,column=0,padx=5,pady=5,sticky="w")
        thinner_txt = Entry(F12, width=8,textvariable=self.thinner, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=7,column=1,padx=5,pady=5)
#         price["thinner"] = self.thinner.get()
        
        #==========PACKETS AND PAPER==========#
        F13=LabelFrame(self.root, bd=10, relief=GROOVE, text="Paper & Packets", font=("times new roman", 15, "bold"), fg="gold", bg=bg_color)
        F13.place(x=510, y=180, width=355, height=405)
        
        #bath_lbl = Label(F2, text="Chandrush", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=0, column=1, padx=10,pady=10)
        #bath_txt = Entry(F2, width=10, font("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=0,column=1,padx=10,pady=10)
        
        alo100_lbl = Label(F13, text="Aloxide 80/100", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=0,column=0,padx=5,pady=5,sticky="w")
        alo100_txt = Entry(F13, width=6,textvariable=self.alo_80, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=0,column=1,padx=5,pady=5)
#         price["alo_80"] = self.alo_80.get()
        
        alo120_lbl = Label(F13, text="Alo 120/150/180/220", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=1,column=0,padx=5,pady=5,sticky="w")
        alo120_txt = Entry(F13, width=6,textvariable=self.alo_120, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=1,column=1,padx=5,pady=5)
#         price["alo_120"] = self.alo_120.get()
        
        sandpaper_lbl = Label(F13, text="Sandpaper (1pc)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=2,column=0,padx=5,pady=5,sticky="w")
        sandpaper_txt = Entry(F13, width=6,textvariable=self.sandpaper, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=2,column=1,padx=5,pady=5)
#         price["sandpaper"] = self.sandpaper.get()
        
        roll_paper_lbl = Label(F13, text="Roll Paper (1m)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=3,column=0,padx=5,pady=5,sticky="w")
        roll_paper_txt = Entry(F13, width=6,textvariable=self.rollpaper, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=3,column=1,padx=5,pady=5)
#         price["rollpaper"] = self.rollpaper.get()
        
        tukda_lbl = Label(F13, text="Brown Tukda", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=4,column=0,padx=5,pady=5,sticky="w")
        tukda_txt = Entry(F13, width=6,textvariable=self.tukda, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=4,column=1,padx=5,pady=5)
#         price["tukda"] = self.tukda.get()
        
        amber_lbl = Label(F13, text="Amber/Ravsena/Bumsena", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=5,column=0,padx=5,pady=5,sticky="w")
        amber_txt = Entry(F13, width=6,textvariable=self.amber, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=5,column=1,padx=5,pady=5)
#         price["amber"] = self.amber.get()
        
        kesari_lbl = Label(F13, text="Kesari/Mithi/Mahogany", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=6,column=0,padx=5,pady=5,sticky="w")
        kesari_txt = Entry(F13, width=6,textvariable=self.kesari, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=6,column=1,padx=5,pady=5)
#         price["kesari"] = self.kesari.get()
        
        zinc_lbl = Label(F13, text="Zinc (100 gm)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=7,column=0,padx=5,pady=5,sticky="w")
        zinc_txt = Entry(F13, width=6,textvariable=self.zinc, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=7,column=1,padx=5,pady=5)
#         price["zinc"] = self.zinc.get()
        
        #==========REST==========#
        F14=LabelFrame(self.root, bd=10, relief=GROOVE, text="Others", font=("times new roman", 15, "bold"), fg="gold", bg=bg_color)
        F14.place(x=870, y=180, width=345, height=500)
        
        #bath_lbl = Label(F2, text="Chandrush", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=0, column=1, padx=10,pady=10)
        #bath_txt = Entry(F2, width=10, font("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=0,column=1,padx=10,pady=10)
        
        dk_lbl = Label(F14, text="DK Thinner (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=0,column=0,padx=5,pady=5,sticky="w")
        dk_txt = Entry(F14, width=8,textvariable=self.dk, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=0,column=1,padx=5,pady=5)
#         price["dk"] = self.dk.get()
        
        wood_matte_lbl = Label(F14, text="WoodPol Matte (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=1,column=0,padx=5,pady=5,sticky="w")
        wood_matte_txt = Entry(F14, width=8,textvariable=self.woodmatte, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=1,column=1,padx=5,pady=5)
#         price["woodmatte"] = self.woodmatte.get()
        
        wood_glossy_lbl = Label(F14, text="WoodPol Glossy (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=2,column=0,padx=5,pady=5,sticky="w")
        wood_glossy_txt = Entry(F14, width=8,textvariable=self.woodglossy, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=2,column=1,padx=5,pady=5)
#         price["woodglossy"] = self.woodglossy.get()
        
        sealer_lbl = Label(F14, text="Sealer (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=3,column=0,padx=5,pady=5,sticky="w")
        sealer_lac_txt = Entry(F14, width=8,textvariable=self.sealer, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=3,column=1,padx=5,pady=5)
#         price["sealer"] = self.sealer.get()
        
        saree_lbl = Label(F14, text="Saree", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=4,column=0,padx=5,pady=5,sticky="w")
        saree_txt = Entry(F14, width=8,textvariable=self.saree, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=4,column=1,padx=5,pady=5)
#         price["saree"] = self.saree.get()
        
        mom_plain_lbl = Label(F14, text="Mom plain", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=5,column=0,padx=5,pady=10,sticky="w")
        mom_plain_txt = Entry(F14, width=8,textvariable=self.momplain, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=5,column=1,padx=5,pady=5)
#         price["momplain"] = self.momplain.get()
        
        mom_matte_lbl = Label(F14, text="Mom matte", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=6,column=0,padx=5,pady=5,sticky="w")
        mom_matte_txt = Entry(F14, width=8,textvariable=self.mommatte, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=6,column=1,padx=5,pady=5)
#         price["mommatte"] = self.mommatte.get()
        
        brush_lbl = Label(F14, text="Dabba (ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=7,column=0,padx=5,pady=5,sticky="w")
        brush_txt = Entry(F14, width=8,textvariable=self.brush, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=7,column=1,padx=5,pady=5)
#         price["brush"] = self.brush.get()
#         pass

        #==========SAVE==========#
        
        btn_F = Frame(F14,bd=7,relief=GROOVE)
        btn_F.place(x=10, y=405, width=305, height=60)
        
        bill_btn = Button(btn_F, text="SAVE", command=self.save_p, bg="cadetblue", fg="white", pady=0, width=35, height=2, bd=5, font="arial 10 bold").grid(row=0,column=0,padx=0,pady=0)
        
        
    def save_p(self):
        global cost
        op=messagebox.askyesno("Save","Do you want to save new prices?")
        if(op>0):
            f1 = open("bills/price.txt","w")
            f1.write(f"{self.lakh.get()},\n")
            f1.close()
            f1 = open("bills/price.txt","a")

            f1.write(f"{self.chandrush.get()},\n")
            f1.write(f"{self.spirit.get()},\n")
            f1.write(f"{self.white.get()},\n")
            f1.write(f"{self.lakh_pwd.get()},\n")
            f1.write(f"{self.chandrush_pwd.get()},\n")
            f1.write(f"{self.rajan.get()},\n")
            f1.write(f"{self.thinner.get()},\n")
            f1.write(f"{self.alo_80.get()},\n")
            f1.write(f"{self.alo_120.get()},\n")
            f1.write(f"{self.sandpaper.get()},\n")
            f1.write(f"{self.rollpaper.get()},\n")
            f1.write(f"{self.tukda.get()},\n")
            f1.write(f"{self.amber.get()},\n")
            f1.write(f"{self.kesari.get()},\n")
            f1.write(f"{self.zinc.get()},\n")
            f1.write(f"{self.dk.get()},\n")
            f1.write(f"{self.woodmatte.get()},\n")
            f1.write(f"{self.woodglossy.get()},\n")
            f1.write(f"{self.sealer.get()},\n")
            f1.write(f"{self.saree.get()},\n")
            f1.write(f"{self.momplain.get()},\n")
            f1.write(f"{self.mommatte.get()},\n")
            f1.write(f"{self.brush.get()},\n")
            f1.close()
            price = {}
            count=0
            with open("bills/price.txt") as fo:
                for rec in fo:
                    price[products[count]] = float(rec.split(",")[0])
                    count +=1
#             print(price)
        else:
            return

        
class cost_window:
    def __init__ (self, root):
        global cost
        self.root=root
        self.root.geometry("1350x750+0+0")
        self.root.title("New Window!")
        bg_color = "#074463"
        title = Label(self.root, text="ENTER NEW COST PRICES", bd=12, relief=GROOVE, bg=bg_color, fg="white", font=("times new roman", 30,"bold"), pady=2).pack(fill=X)
        
        #POLISH#
        self.lakh = DoubleVar()
        self.chandrush = DoubleVar()
        self.spirit = DoubleVar()
        self.white = DoubleVar()
        self.lakh_pwd = DoubleVar()
        self.chandrush_pwd = DoubleVar()
        self.rajan = DoubleVar()
        self.thinner = DoubleVar()
        
        #P&P#
        self.alo_80 = DoubleVar()
        self.alo_120 = DoubleVar()
        self.sandpaper = DoubleVar()
        self.rollpaper = DoubleVar()
        self.tukda = DoubleVar()
        self.amber = DoubleVar()
        self.kesari = DoubleVar()
        self.zinc = DoubleVar()
        
        #OTHERS#
        self.dk = DoubleVar()
        self.woodmatte = DoubleVar()
        self.woodglossy = DoubleVar()
        self.sealer = DoubleVar()
        self.saree = DoubleVar()
        self.momplain = DoubleVar()
        self.mommatte = DoubleVar()
        self.brush = DoubleVar()
        
        #Set variable values#
        #POLISH#
        self.lakh.set(cost["lakh"])
        self.chandrush.set(cost["chandrush"])
        self.spirit.set(cost["spirit"])
        self.white.set(cost["white"])
        self.lakh_pwd.set(cost["lakh_pwd"])
        self.chandrush_pwd.set(cost["chandrush_pwd"])
        self.rajan.set(cost["rajan"])
        self.thinner.set(cost["thinner"])

        #P&P#
        self.alo_80.set(cost["alo_80"])
        self.alo_120.set(cost["alo_120"])
        self.sandpaper.set(cost["sandpaper"])
        self.rollpaper.set(cost["rollpaper"])
        self.tukda.set(cost["tukda"])
        self.amber.set(cost["amber"])
        self.kesari.set(cost["kesari"])
        self.zinc.set(cost["zinc"])

        #OTHERS#
        self.dk.set(cost["dk"])
        self.woodmatte.set(cost["woodmatte"])
        self.woodglossy.set(cost["woodglossy"])
        self.sealer.set(cost["sealer"])
        self.saree.set(cost["saree"])
        self.momplain.set(cost["momplain"])
        self.mommatte.set(cost["mommatte"])
        self.brush.set(cost["brush"])
        
        #==========COSMETIC FRAME==========#
        F22=LabelFrame(self.root, bd=10, relief=GROOVE, text="Polish", font=("times new roman", 15, "bold"), fg="gold", bg=bg_color)
        F22.place(x=155, y=180, width=350, height=405)
        
        #bath_lbl = Label(F2, text="Chandrush", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=0, column=1, padx=10,pady=10)
        #bath_txt = Entry(F2, width=10, font("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=0,column=1,padx=10,pady=10)
        
        lakh_lbl = Label(F22, text="Lac Polish (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=0,column=0,padx=5,pady=5,sticky="w")
        lakh_txt = Entry(F22, width=8, textvariable=self.lakh, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=0,column=1,padx=5,pady=5)
#         cost["lakh"] = self.lakh.get()
        
        chandrush_lbl = Label(F22, text="Chandrush (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=1,column=0,padx=5,pady=5,sticky="w")
        chandrush_txt = Entry(F22, width=8,textvariable=self.chandrush, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=1,column=1,padx=5,pady=5)
#         cost["chandrush"] = self.chandrush.get()
        
        spirit_lbl = Label(F22, text="Spirit (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=2,column=0,padx=5,pady=5,sticky="w")
        spirit_txt = Entry(F22, width=8,textvariable=self.spirit, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=2,column=1,padx=5,pady=5)
#         cost["spirit"] = self.spirit.get()
        
        white_lac_lbl = Label(F22, text="White Lac (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=3,column=0,padx=5,pady=5,sticky="w")
        white_lac_txt = Entry(F22, width=8,textvariable=self.white, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=3,column=1,padx=5,pady=5)
#         cost["white"] = self.white.get()
        
        lac_pwd_lbl = Label(F22, text="Lac pwd (1 kg)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=4,column=0,padx=5,pady=5,sticky="w")
        lac_pwd_txt = Entry(F22, width=8,textvariable=self.lakh_pwd, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=4,column=1,padx=5,pady=5)
#         cost["lakh_pwd"] = self.lakh_pwd.get()
        
        chand_pwd_lbl = Label(F22, text="Chandrush pwd (1 kg)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=5,column=0,padx=5,pady=10,sticky="w")
        chand_pwd_txt = Entry(F22, width=8,textvariable=self.chandrush_pwd, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=5,column=1,padx=5,pady=5)
#         cost["chandrush_pwd"] = self.chandrush_pwd.get()
        
        rajan_lbl = Label(F22, text="Rajan/Rosin (1 kg)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=6,column=0,padx=5,pady=5,sticky="w")
        rajan_txt = Entry(F22, width=8,textvariable=self.rajan, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=6,column=1,padx=5,pady=5)
#         cost["rajan"] = self.rajan.get()
        
        thinner_lbl = Label(F22, text="Ameya Thinner (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=7,column=0,padx=5,pady=5,sticky="w")
        thinner_txt = Entry(F22, width=8,textvariable=self.thinner, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=7,column=1,padx=5,pady=5)
#         cost["thinner"] = self.thinner.get()
        
        #==========PACKETS AND PAPER==========#
        F23=LabelFrame(self.root, bd=10, relief=GROOVE, text="Paper & Packets", font=("times new roman", 15, "bold"), fg="gold", bg=bg_color)
        F23.place(x=510, y=180, width=355, height=405)
        
        #bath_lbl = Label(F2, text="Chandrush", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=0, column=1, padx=10,pady=10)
        #bath_txt = Entry(F2, width=10, font("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=0,column=1,padx=10,pady=10)
        
        alo100_lbl = Label(F23, text="Aloxide 80/100", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=0,column=0,padx=5,pady=5,sticky="w")
        alo100_txt = Entry(F23, width=6,textvariable=self.alo_80, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=0,column=1,padx=5,pady=5)
#         cost["alo_80"] = self.alo_80.get()
        
        alo120_lbl = Label(F23, text="Alo 120/150/180/220", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=1,column=0,padx=5,pady=5,sticky="w")
        alo120_txt = Entry(F23, width=6,textvariable=self.alo_120, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=1,column=1,padx=5,pady=5)
#         cost["alo_120"] = self.alo_120.get()
        
        sandpaper_lbl = Label(F23, text="Sandpaper (1pc)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=2,column=0,padx=5,pady=5,sticky="w")
        sandpaper_txt = Entry(F23, width=6,textvariable=self.sandpaper, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=2,column=1,padx=5,pady=5)
#         cost["sandpaper"] = self.sandpaper.get()
        
        roll_paper_lbl = Label(F23, text="Roll Paper (1m)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=3,column=0,padx=5,pady=5,sticky="w")
        roll_paper_txt = Entry(F23, width=6,textvariable=self.rollpaper, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=3,column=1,padx=5,pady=5)
#         cost["rollpaper"] = self.rollpaper.get()
        
        tukda_lbl = Label(F23, text="Brown Tukda", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=4,column=0,padx=5,pady=5,sticky="w")
        tukda_txt = Entry(F23, width=6,textvariable=self.tukda, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=4,column=1,padx=5,pady=5)
#         cost["tukda"] = self.tukda.get()
        
        amber_lbl = Label(F23, text="Amber/Ravsena/Bumsena", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=5,column=0,padx=5,pady=5,sticky="w")
        amber_txt = Entry(F23, width=6,textvariable=self.amber, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=5,column=1,padx=5,pady=5)
#         cost["amber"] = self.amber.get()
        
        kesari_lbl = Label(F23, text="Kesari/Mithi/Mahogany", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=6,column=0,padx=5,pady=5,sticky="w")
        kesari_txt = Entry(F23, width=6,textvariable=self.kesari, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=6,column=1,padx=5,pady=5)
#         cost["kesari"] = self.kesari.get()
        
        zinc_lbl = Label(F23, text="Zinc (100 gm)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=7,column=0,padx=5,pady=5,sticky="w")
        zinc_txt = Entry(F23, width=6,textvariable=self.zinc, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=7,column=1,padx=5,pady=5)
#         cost["zinc"] = self.zinc.get()
        
        #==========REST==========#
        F24=LabelFrame(self.root, bd=10, relief=GROOVE, text="Others", font=("times new roman", 15, "bold"), fg="gold", bg=bg_color)
        F24.place(x=870, y=180, width=345, height=500)
        
        #bath_lbl = Label(F2, text="Chandrush", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=0, column=1, padx=10,pady=10)
        #bath_txt = Entry(F2, width=10, font("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=0,column=1,padx=10,pady=10)
        
        dk_lbl = Label(F24, text="DK Thinner (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=0,column=0,padx=5,pady=5,sticky="w")
        dk_txt = Entry(F24, width=8,textvariable=self.dk, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=0,column=1,padx=5,pady=5)
#         cost["dk"] = self.dk.get()
        
        wood_matte_lbl = Label(F24, text="WoodPol Matte (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=1,column=0,padx=5,pady=5,sticky="w")
        wood_matte_txt = Entry(F24, width=8,textvariable=self.woodmatte, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=1,column=1,padx=5,pady=5)
#         cost["woodmatte"] = self.woodmatte.get()
        
        wood_glossy_lbl = Label(F24, text="WoodPol Glossy (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=2,column=0,padx=5,pady=5,sticky="w")
        wood_glossy_txt = Entry(F24, width=8,textvariable=self.woodglossy, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=2,column=1,padx=5,pady=5)
#         cost["woodglossy"] = self.woodglossy.get()
        
        sealer_lbl = Label(F24, text="Sealer (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=3,column=0,padx=5,pady=5,sticky="w")
        sealer_lac_txt = Entry(F24, width=8,textvariable=self.sealer, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=3,column=1,padx=5,pady=5)
#         cost["sealer"] = self.sealer.get()
        
        saree_lbl = Label(F24, text="Saree", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=4,column=0,padx=5,pady=5,sticky="w")
        saree_txt = Entry(F24, width=8,textvariable=self.saree, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=4,column=1,padx=5,pady=5)
#         cost["saree"] = self.saree.get()
        
        mom_plain_lbl = Label(F24, text="Mom plain", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=5,column=0,padx=5,pady=10,sticky="w")
        mom_plain_txt = Entry(F24, width=8,textvariable=self.momplain, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=5,column=1,padx=5,pady=5)
#         cost["momplain"] = self.momplain.get()
        
        mom_matte_lbl = Label(F24, text="Mom matte", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=6,column=0,padx=5,pady=5,sticky="w")
        mom_matte_txt = Entry(F24, width=8,textvariable=self.mommatte, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=6,column=1,padx=5,pady=5)
#         cost["mommatte"] = self.mommatte.get()
        
        brush_lbl = Label(F24, text="Dabba (ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=7,column=0,padx=5,pady=5,sticky="w")
        brush_txt = Entry(F24, width=8,textvariable=self.brush, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=7,column=1,padx=5,pady=5)
#         cost["brush"] = self.brush.get()
#        pass
        
        #==========SAVE==========#
        
        btn_F = Frame(F24,bd=7,relief=GROOVE)
        btn_F.place(x=10, y=405, width=305, height=60)
        
        bill_btn = Button(btn_F, text="SAVE", command=self.save_c, bg="cadetblue", fg="white", pady=0, width=35, height=2, bd=5, font="arial 10 bold").grid(row=0,column=0,padx=0,pady=0)
        
        
    def save_c(self):
        global cost
        op=messagebox.askyesno("Save","Do you want to save new costings?")
        if(op>0):
            f1 = open("bills/cost.txt","w")
            f1.write(f"{self.lakh.get()},\n")
            f1.close()
            f1 = open("bills/cost.txt","a")

            f1.write(f"{self.chandrush.get()},\n")
            f1.write(f"{self.spirit.get()},\n")
            f1.write(f"{self.white.get()},\n")
            f1.write(f"{self.lakh_pwd.get()},\n")
            f1.write(f"{self.chandrush_pwd.get()},\n")
            f1.write(f"{self.rajan.get()},\n")
            f1.write(f"{self.thinner.get()},\n")
            f1.write(f"{self.alo_80.get()},\n")
            f1.write(f"{self.alo_120.get()},\n")
            f1.write(f"{self.sandpaper.get()},\n")
            f1.write(f"{self.rollpaper.get()},\n")
            f1.write(f"{self.tukda.get()},\n")
            f1.write(f"{self.amber.get()},\n")
            f1.write(f"{self.kesari.get()},\n")
            f1.write(f"{self.zinc.get()},\n")
            f1.write(f"{self.dk.get()},\n")
            f1.write(f"{self.woodmatte.get()},\n")
            f1.write(f"{self.woodglossy.get()},\n")
            f1.write(f"{self.sealer.get()},\n")
            f1.write(f"{self.saree.get()},\n")
            f1.write(f"{self.momplain.get()},\n")
            f1.write(f"{self.mommatte.get()},\n")
            f1.write(f"{self.brush.get()},\n")
            f1.close()
            cost = {}
            count=0
            with open("bills/cost.txt") as fo:
                for rec in fo:
                    cost[products[count]] = float(rec.split(",")[0])
                    count +=1
            #print(cost)
        else:
            return
        
class stock_window:
    def __init__ (self, root):
        global cost
        global stock
        global total_stock
        self.root=root
        self.root.geometry("1350x750+0+0")
        self.root.title("Stock Window")
        bg_color = "#074463"
        title = Label(self.root, text="ADD STOCK", bd=12, relief=GROOVE, bg=bg_color, fg="white", font=("times new roman", 30,"bold"), pady=2).pack(fill=X)
        
        #POLISH#
        self.lakh = DoubleVar()
        self.chandrush = DoubleVar()
        self.spirit = DoubleVar()
        self.white = DoubleVar()
        self.lakh_pwd = DoubleVar()
        self.chandrush_pwd = DoubleVar()
        self.rajan = DoubleVar()
        self.thinner = DoubleVar()
        
        #P&P#
        self.alo_80 = DoubleVar()
        self.alo_120 = DoubleVar()
        self.sandpaper = DoubleVar()
        self.rollpaper = DoubleVar()
        self.tukda = DoubleVar()
        self.amber = DoubleVar()
        self.kesari = DoubleVar()
        self.zinc = DoubleVar()
        
        #OTHERS#
        self.dk = DoubleVar()
        self.woodmatte = DoubleVar()
        self.woodglossy = DoubleVar()
        self.sealer = DoubleVar()
        self.saree = DoubleVar()
        self.momplain = DoubleVar()
        self.mommatte = DoubleVar()
        self.brush = DoubleVar()
        
#         #Set as original#
#         #POLISH#
#         self.lakh.set(total_stock["lakh"])
#         self.chandrush.set(total_stock["chandrush"])
#         self.spirit.set(total_stock["spirit"])
#         self.white.set(total_stock["white"])
#         self.lakh_pwd.set(total_stock["lakh_pwd"])
#         self.chandrush_pwd.set(total_stock["chandrush_pwd"])
#         self.rajan.set(total_stock["rajan"])
#         self.thinner.set(total_stock["thinner"])

#         #P&P#
#         self.alo_80.set(total_stock["alo_80"])
#         self.alo_120.set(total_stock["alo_120"])
#         self.sandpaper.set(total_stock["sandpaper"])
#         self.rollpaper.set(total_stock["rollpaper"])
#         self.tukda.set(total_stock["tukda"])
#         self.amber.set(total_stock["amber"])
#         self.kesari.set(total_stock["kesari"])
#         self.zinc.set(total_stock["zinc"])

#         #OTHERS#
#         self.dk.set(total_stock["dk"])
#         self.woodmatte.set(total_stock["woodmatte"])
#         self.woodglossy.set(total_stock["woodglossy"])
#         self.sealer.set(total_stock["sealer"])
#         self.saree.set(total_stock["saree"])
#         self.momplain.set(total_stock["momplain"])
#         self.mommatte.set(total_stock["mommatte"])
#         self.brush.set(total_stock["brush"])
        #POLISH#
        self.lakh.set(0)
        self.chandrush.set(0)
        self.spirit.set(0)
        self.white.set(0)
        self.lakh_pwd.set(0)
        self.chandrush_pwd.set(0)
        self.rajan.set(0)
        self.thinner.set(0)

        #P&P#
        self.alo_80.set(0)
        self.alo_120.set(0)
        self.sandpaper.set(0)
        self.rollpaper.set(0)
        self.tukda.set(0)
        self.amber.set(0)
        self.kesari.set(0)
        self.zinc.set(0)

        #OTHERS#
        self.dk.set(0)
        self.woodmatte.set(0)
        self.woodglossy.set(0)
        self.sealer.set(0)
        self.saree.set(0)
        self.momplain.set(0)
        self.mommatte.set(0)
        self.brush.set(0)
        
        #==========COSMETIC FRAME==========#
        F32=LabelFrame(self.root, bd=10, relief=GROOVE, text="Polish", font=("times new roman", 15, "bold"), fg="gold", bg=bg_color)
        F32.place(x=155, y=180, width=350, height=405)
        
        #bath_lbl = Label(F2, text="Chandrush", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=0, column=1, padx=10,pady=10)
        #bath_txt = Entry(F2, width=10, font("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=0,column=1,padx=10,pady=10)
        
        lakh_lbl = Label(F32, text="Lac Polish (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=0,column=0,padx=5,pady=5,sticky="w")
        lakh_txt = Entry(F32, width=8, textvariable=self.lakh, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=0,column=1,padx=5,pady=5)
        stock["lakh"] = self.lakh.get()
        
        chandrush_lbl = Label(F32, text="Chandrush (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=1,column=0,padx=5,pady=5,sticky="w")
        chandrush_txt = Entry(F32, width=8,textvariable=self.chandrush, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=1,column=1,padx=5,pady=5)
        stock["chandrush"] = self.chandrush.get()
        
        spirit_lbl = Label(F32, text="Spirit (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=2,column=0,padx=5,pady=5,sticky="w")
        spirit_txt = Entry(F32, width=8,textvariable=self.spirit, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=2,column=1,padx=5,pady=5)
        stock["spirit"] = self.spirit.get()
        
        white_lac_lbl = Label(F32, text="White Lac (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=3,column=0,padx=5,pady=5,sticky="w")
        white_lac_txt = Entry(F32, width=8,textvariable=self.white, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=3,column=1,padx=5,pady=5)
        stock["white"] = self.white.get()
        
        lac_pwd_lbl = Label(F32, text="Lac pwd (1 kg)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=4,column=0,padx=5,pady=5,sticky="w")
        lac_pwd_txt = Entry(F32, width=8,textvariable=self.lakh_pwd, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=4,column=1,padx=5,pady=5)
        stock["lakh_pwd"] = self.lakh_pwd.get()
        
        chand_pwd_lbl = Label(F32, text="Chandrush pwd (1 kg)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=5,column=0,padx=5,pady=10,sticky="w")
        chand_pwd_txt = Entry(F32, width=8,textvariable=self.chandrush_pwd, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=5,column=1,padx=5,pady=5)
        stock["chandrush_pwd"] = self.chandrush_pwd.get()
        
        rajan_lbl = Label(F32, text="Rajan/Rosin (1 kg)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=6,column=0,padx=5,pady=5,sticky="w")
        rajan_txt = Entry(F32, width=8,textvariable=self.rajan, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=6,column=1,padx=5,pady=5)
        stock["rajan"] = self.rajan.get()
        
        thinner_lbl = Label(F32, text="Ameya Thinner (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=7,column=0,padx=5,pady=5,sticky="w")
        thinner_txt = Entry(F32, width=8,textvariable=self.thinner, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=7,column=1,padx=5,pady=5)
        stock["thinner"] = self.thinner.get()
        
        #==========PACKETS AND PAPER==========#
        F33=LabelFrame(self.root, bd=10, relief=GROOVE, text="Paper & Packets", font=("times new roman", 15, "bold"), fg="gold", bg=bg_color)
        F33.place(x=510, y=180, width=355, height=405)
        
        #bath_lbl = Label(F2, text="Chandrush", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=0, column=1, padx=10,pady=10)
        #bath_txt = Entry(F2, width=10, font("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=0,column=1,padx=10,pady=10)
        
        alo100_lbl = Label(F33, text="Aloxide 80/100", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=0,column=0,padx=5,pady=5,sticky="w")
        alo100_txt = Entry(F33, width=6,textvariable=self.alo_80, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=0,column=1,padx=5,pady=5)
        stock["alo_80"] = self.alo_80.get()
        
        alo120_lbl = Label(F33, text="Alo 120/150/180/220", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=1,column=0,padx=5,pady=5,sticky="w")
        alo120_txt = Entry(F33, width=6,textvariable=self.alo_120, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=1,column=1,padx=5,pady=5)
        stock["alo_120"] = self.alo_120.get()
        
        sandpaper_lbl = Label(F33, text="Sandpaper (1pc)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=2,column=0,padx=5,pady=5,sticky="w")
        sandpaper_txt = Entry(F33, width=6,textvariable=self.sandpaper, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=2,column=1,padx=5,pady=5)
        stock["sandpaper"] = self.sandpaper.get()
        
        roll_paper_lbl = Label(F33, text="Roll Paper (1m)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=3,column=0,padx=5,pady=5,sticky="w")
        roll_paper_txt = Entry(F33, width=6,textvariable=self.rollpaper, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=3,column=1,padx=5,pady=5)
        stock["rollpaper"] = self.rollpaper.get()
        
        tukda_lbl = Label(F33, text="Brown Tukda", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=4,column=0,padx=5,pady=5,sticky="w")
        tukda_txt = Entry(F33, width=6,textvariable=self.tukda, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=4,column=1,padx=5,pady=5)
        stock["tukda"] = self.tukda.get()
        
        amber_lbl = Label(F33, text="Amber/Ravsena/Bumsena", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=5,column=0,padx=5,pady=5,sticky="w")
        amber_txt = Entry(F33, width=6,textvariable=self.amber, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=5,column=1,padx=5,pady=5)
        stock["amber"] = self.amber.get()
        
        kesari_lbl = Label(F33, text="Kesari/Mithi/Mahogany", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=6,column=0,padx=5,pady=5,sticky="w")
        kesari_txt = Entry(F33, width=6,textvariable=self.kesari, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=6,column=1,padx=5,pady=5)
        stock["kesari"] = self.kesari.get()
        
        zinc_lbl = Label(F33, text="Zinc (100 gm)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=7,column=0,padx=5,pady=5,sticky="w")
        zinc_txt = Entry(F33, width=6,textvariable=self.zinc, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=7,column=1,padx=5,pady=5)
        stock["zinc"] = self.zinc.get()
        
        #==========REST==========#
        F34=LabelFrame(self.root, bd=10, relief=GROOVE, text="Others", font=("times new roman", 15, "bold"), fg="gold", bg=bg_color)
        F34.place(x=870, y=180, width=345, height=500)
        
        #bath_lbl = Label(F2, text="Chandrush", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=0, column=1, padx=10,pady=10)
        #bath_txt = Entry(F2, width=10, font("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=0,column=1,padx=10,pady=10)
        
        dk_lbl = Label(F34, text="DK Thinner (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=0,column=0,padx=5,pady=5,sticky="w")
        dk_txt = Entry(F34, width=8,textvariable=self.dk, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=0,column=1,padx=5,pady=5)
        stock["dk"] = self.dk.get()
        
        wood_matte_lbl = Label(F34, text="WoodPol Matte (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=1,column=0,padx=5,pady=5,sticky="w")
        wood_matte_txt = Entry(F34, width=8,textvariable=self.woodmatte, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=1,column=1,padx=5,pady=5)
        stock["woodmatte"] = self.woodmatte.get()
        
        wood_glossy_lbl = Label(F34, text="WoodPol Glossy (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=2,column=0,padx=5,pady=5,sticky="w")
        wood_glossy_txt = Entry(F34, width=8,textvariable=self.woodglossy, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=2,column=1,padx=5,pady=5)
        stock["woodglossy"] = self.woodglossy.get()
        
        sealer_lbl = Label(F34, text="Sealer (1 ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=3,column=0,padx=5,pady=5,sticky="w")
        sealer_lac_txt = Entry(F34, width=8,textvariable=self.sealer, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=3,column=1,padx=5,pady=5)
        stock["sealer"] = self.sealer.get()
        
        saree_lbl = Label(F34, text="Saree", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=4,column=0,padx=5,pady=5,sticky="w")
        saree_txt = Entry(F34, width=8,textvariable=self.saree, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=4,column=1,padx=5,pady=5)
        stock["saree"] = self.saree.get()
        
        mom_plain_lbl = Label(F34, text="Mom plain", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=5,column=0,padx=5,pady=10,sticky="w")
        mom_plain_txt = Entry(F34, width=8,textvariable=self.momplain, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=5,column=1,padx=5,pady=5)
        stock["momplain"] = self.momplain.get()
        
        mom_matte_lbl = Label(F34, text="Mom matte", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=6,column=0,padx=5,pady=5,sticky="w")
        mom_matte_txt = Entry(F34, width=8,textvariable=self.mommatte, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=6,column=1,padx=5,pady=5)
        stock["mommatte"] = self.mommatte.get()
        
        brush_lbl = Label(F34, text="Dabba (ltr)", font=("times new roman",16,"bold"), bg=bg_color, fg="lightgreen").grid(row=7,column=0,padx=5,pady=5,sticky="w")
        brush_txt = Entry(F34, width=8,textvariable=self.brush, font=("times new roman",16,"bold"),bd=5,relief=SUNKEN).grid(row=7,column=1,padx=5,pady=5)
        stock["brush"] = self.brush.get()
#        pass
        #print(stock)
        #==========SAVE==========#
        
        btn_F = Frame(F34,bd=7,relief=GROOVE)
        btn_F.place(x=10, y=405, width=305, height=60)
        
        bill_btn = Button(btn_F, text="SAVE", command=self.save_s, bg="cadetblue", fg="white", pady=0, width=35, height=2, bd=5, font="arial 10 bold").grid(row=0,column=0,padx=0,pady=0)
        
        
    def save_s(self):
        global cost
        global total_stock
        op=messagebox.askyesno("Save","Do you want to add new stock?")
        if(op>0):
#             f1 = open("bills/cost.txt","w")
#             f1.write(f"{self.lakh.get()},\n")
#             f1.close()
#             f1 = open("bills/cost.txt","a")

#             f1.write(f"{self.chandrush.get()},\n")
#             f1.write(f"{self.spirit.get()},\n")
#             f1.write(f"{self.white.get()},\n")
#             f1.write(f"{self.lakh_pwd.get()},\n")
#             f1.write(f"{self.chandrush_pwd.get()},\n")
#             f1.write(f"{self.rajan.get()},\n")
#             f1.write(f"{self.thinner.get()},\n")
#             f1.write(f"{self.alo_80.get()},\n")
#             f1.write(f"{self.alo_120.get()},\n")
#             f1.write(f"{self.sandpaper.get()},\n")
#             f1.write(f"{self.rollpaper.get()},\n")
#             f1.write(f"{self.tukda.get()},\n")
#             f1.write(f"{self.amber.get()},\n")
#             f1.write(f"{self.kesari.get()},\n")
#             f1.write(f"{self.zinc.get()},\n")
#             f1.write(f"{self.dk.get()},\n")
#             f1.write(f"{self.woodmatte.get()},\n")
#             f1.write(f"{self.woodglossy.get()},\n")
#             f1.write(f"{self.sealer.get()},\n")
#             f1.write(f"{self.saree.get()},\n")
#             f1.write(f"{self.momplain.get()},\n")
#             f1.write(f"{self.mommatte.get()},\n")
#             f1.write(f"{self.brush.get()},\n")
#             f1.close()
            stock = {}
            stock["lakh"] = self.lakh.get()

            stock["chandrush"] = self.chandrush.get()

            stock["spirit"] = self.spirit.get()

            stock["white"] = self.white.get()

            stock["lakh_pwd"] = self.lakh_pwd.get()

            stock["chandrush_pwd"] = self.chandrush_pwd.get()

            stock["rajan"] = self.rajan.get()

            stock["thinner"] = self.thinner.get()

            stock["alo_80"] = self.alo_80.get()

            stock["alo_120"] = self.alo_120.get()

            stock["sandpaper"] = self.sandpaper.get()

            stock["rollpaper"] = self.rollpaper.get()

            stock["tukda"] = self.tukda.get()

            stock["amber"] = self.amber.get()

            stock["kesari"] = self.kesari.get()

            stock["zinc"] = self.zinc.get()

            stock["dk"] = self.dk.get()

            stock["woodmatte"] = self.woodmatte.get()

            stock["woodglossy"] = self.woodglossy.get()

            stock["sealer"] = self.sealer.get()

            stock["saree"] = self.saree.get()

            stock["momplain"] = self.momplain.get()

            stock["mommatte"] = self.mommatte.get()

            stock["brush"] = self.brush.get()

            #print(stock)
            total_stock = {}
            count=0
            with open("bills/stock_total.txt") as fo:
                for rec in fo:
                    total_stock[products[count]] = float(rec.split(",")[0])
                    count +=1
    
            stock_sum = {}
            for i in range(len(products)):
                stock_sum[products[i]] = total_stock[products[i]]+stock[products[i]]
            total_stock = stock_sum
#             print("New quantity_day: ")
#             print(quantity_day)
            
            temp=total_stock["lakh"]
            f1=open("bills/stock_total.txt","w")
            f1.write(str(temp)+",\n")
            f1.close()
            
            f1=open("bills/stock_total.txt","a")
            for i in range(len(products)-1):
                temp = total_stock[products[i+1]]
                f1.write(str(temp)+",\n")
            f1.close()

            total_stock = {}
            count=0
            with open("bills/cost.txt") as fo:
                for rec in fo:
                    total_stock[products[count]] = float(rec.split(",")[0])
                    count +=1
            #print(cost)
        else:
            return
        
        
        
        



def month_over():
    total_profit += monthly_profit
    for i in quantity_month:
        quantity[i] +=quantity_month[i]
        quantity_month[i] = 0.0
    monthly_profit = 0.0
        
        
root = Tk()
obj = Bill_App(root)
root.mainloop()

# def supreme():
#     nx = Tk()
#     nx.geometry("1350x750+0+0")
#     nx.title("Order Repository")
 

   # def password():
#     login = Tk()
#     login.geometry("400x150")
#     login.title("Daily Data Sheet")
#     password = stringVar()
#     #title = Label(self.root, text="Enter Password", bd=5, relief=GROOVE, bg="#074463", fg="white", font=("times new roman", 30,"bold"), pady=2).pack(fill=X)
#     password_lbl=Label(login, text="PASSWORD: ", bg=bg_color, fg="white", font=("times new roman", 15, "bold")).grid(row=0, column=0, padx=5, pady=5)
#     password_txt=Entry(login, width=18, textvariable=password, show="73*", bd=7, relief=SUNKEN).grid(row=0, column=1, padx=5, pady=5)
#     loginButton = Button(login, text="Login", command=validateLogin).grid(row=2, column=0)
    
# def validateLogin():
